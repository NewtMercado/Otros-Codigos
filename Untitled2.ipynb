# %%
import numpy as np

def f(x):
    if ejercicio == 1:
        return x*3 - 2.(x**2) - 5.
    elif ejercicio == 2:
        return x*3 + 3.(x**2) - 1.
    elif ejercicio == 3:
        return x - np.cos(x)
    elif ejercicio == 4:
        return x - 0.8 - 0.2*np.sin(x) 

def bisec(a,b,tol):
    iter = 0
    if np.abs(f(a)) <= tol:
        return a,0,iter
    elif np.abs(f(b)) <= tol:
        return b,0,iter
    elif f(a)*f(b) > 0.:
        print("No hay raiz en el intervalo dado.")
    else:
        p = (a + b) / 2.

        while (iter <= maxiter and np.abs(f(p)) > tol):
            iter = iter + 1 # iter += 1

            if (f(a)*f(p) < 0):
                b = p
            else:
                a = p
            
            p = (a + b) / 2.
        
        return p,np.abs(f(p)),iter
    
tol = 1e-4
maxiter = 1000

metodo = int(input("Elija el metodo a usar (1, 2 o 3): "))

if metodo == 1:
    ejercicio = int(input("Elija el ejercicio a resolver (1, 2, 3 o 4):"))

    if ejercicio == 1:
        a = 1
        b = 4
    elif ejercicio == 2:
        a = -3
        b = -2

raiz,error,iteraciones=bisec(a,b,tol)
print("La raiz es: ", raiz)
print("El error es: ", error)
print("El numero de iteracines fue: ", iteraciones)
# Out:
# <>:5: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:7: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:5: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:7: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <ipython-input-9-6cb91a714e26>:5: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   return x*3 - 2.(x**2) - 5.
# <ipython-input-9-6cb91a714e26>:7: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   return x*3 + 3.(x**2) - 1.
# Elija el metodo a usar (1, 2 o 3): 1
# Elija el ejercicio a resolver (1, 2, 3 o 4):1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6cb91a714e26> in <module>
#      49         b = -2
#      50
# ---> 51 raiz,error,iteraciones=bisec(a,b,tol)
#      52 print("La raiz es: ", raiz)
#      53 print("El error es: ", error)
#
# <ipython-input-9-6cb91a714e26> in bisec(a, b, tol)
#      13 def bisec(a,b,tol):
#      14     iter = 0
# ---> 15     if np.abs(f(a)) <= tol:
#      16         return a,0,iter
#      17     elif np.abs(f(b)) <= tol:
#
# <ipython-input-9-6cb91a714e26> in f(x)
#       3 def f(x):
#       4     if ejercicio == 1:
# ----> 5         return x*3 - 2.(x**2) - 5.
#       6     elif ejercicio == 2:
#       7         return x*3 + 3.(x**2) - 1.
#
# TypeError: 'float' object is not callable
