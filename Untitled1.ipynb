# %%
o= int(input("digite 1 si quiere convertir de decimal a binario o 2 si quiera convertir a binario a decimal:"))
#o = opcion=%
if o == 1:
  numero = int(input("Introduce un numero decimal: "))
  def binarizar(decimal):
    binario = ''
    while decimal // 2 != 0:
        binario = str(decimal % 2) + binario
        decimal = decimal // 2
    return str(decimal) + binario
  print("el numero en binario es: ",binarizar(numero))

elif(o == 2):

 binario = int(input("digite su número en binario: "))
 decimal = 0
 i = 0
 while (binario>0):
    digito  = binario%10
    binario = int(binario//10)
    decimal = decimal+digito*(2**i)
    i = i+1
print("su numero en decimal es: ",decimal)
# Out:
# digite 1 si quiere convertir de decimal a binario o 2 si quiera convertir a binario a decimal:1
# Introduce un numero decimal: 1
# el numero en binario es:  1
# su numero en decimal es:  9
